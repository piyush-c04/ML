# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir("C:\\Users\\chaud\\Downloads")

# %%
df = pd.read_csv('C:\\Users\\chaud\\Downloads\\netflix_titles.csv')

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.size
# Out:
# 105684

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#       index show_id     type                  title         director  \
# 0         0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         1      s2  TV Show          Blood & Water              NaN
# 2         2      s3  TV Show              Ganglands  Julien Leclercq
# 3         3      s4  TV Show  Jailbirds New Orleans              NaN
# 4         4      s5  TV Show           Kota Factory              NaN
# ...     ...     ...      ...                    ...              ...
# 8802   8802   s8803    Movie                 Zodiac    David Fincher
# 8803   8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       index show_id     type                          title  \
# 7         7      s8    Movie                        Sankofa
# 8         8      s9  TV Show  The Great British Baking Show
# 9         9     s10    Movie                   The Starling
# 12       12     s13    Movie                   Je Suis Karl
# 24       24     s25    Movie                          Jeans
# ...     ...     ...      ...                            ...
# 8801   8801   s8802    Movie                        Zinzana
# 8802   8802   s8803    Movie                         Zodiac
# 8804   8804   s8805    Movie                     Zombieland
# 8805   8805   s8806    Movie                           Zoom
# 8806   8806   s8807    Movie                         Zubaan
#
#                  director                                               cast  \
# 7            Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8         Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#       index show_id     type                          title  \
# 0         7      s8    Movie                        Sankofa
# 1         8      s9  TV Show  The Great British Baking Show
# 2         9     s10    Movie                   The Starling
# 3        12     s13    Movie                   Je Suis Karl
# 4        24     s25    Movie                          Jeans
# ...     ...     ...      ...                            ...
# 5327   8801   s8802    Movie                        Zinzana
# 5328   8802   s8803    Movie                         Zodiac
# 5329   8804   s8805    Movie                     Zombieland
# 5330   8805   s8806    Movie                           Zoom
# 5331   8806   s8807    Movie                         Zubaan
#
#                  director                                               cast  \
# 0            Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1         Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
df1_rows = df[(df['type'] == 'Movie') & (df['release_year'] == 2021) ]
num_rows = df1_rows.shape[0]
num_rows
# Out:
# 146

# %%
df2 = df.groupby(['country' , 'type']).size()

# %%
df2
# Out:
# country                                              type
# , France, Algeria                                    Movie       1
# Argentina                                            Movie      34
#                                                      TV Show     1
# Argentina, Brazil, France, Poland, Germany, Denmark  Movie       1
# Argentina, Chile                                     Movie       2
#                                                                 ..
# Uruguay, Guatemala                                   Movie       1
# Uruguay, Spain, Mexico                               Movie       1
# Venezuela                                            Movie       1
# Vietnam                                              Movie       7
# Zimbabwe                                             Movie       1
# Length: 637, dtype: int64

# %%
avengers_movies = df[df['title'].str.contains('Avengers')]

# %%
avengers_movies
# Out:
#       index show_id   type                                            title  \
# 2934   5340   s5341  Movie  LEGO Marvel Super Heroes: Avengers Reassembled!
# 3500   6200   s6201  Movie                           Avengers: Infinity War
#
#                       director  \
# 2934             Rob Silvestri
# 3500  Anthony Russo, Joe Russo
#
#                                                    cast        country  \
# 2934  Laura Bailey, Troy Baker, Eric Bauza, Ben Disk...  United States
# 3500  Robert Downey Jr., Josh Brolin, Mark Ruffalo, ...  United States
#
#              date_added  release_year rating duration  \
# 2934     August 6, 2017          2015  TV-Y7   22 min
# 3500  December 25, 2018          2018  PG-13  150 min
#
#                                  listed_in  \
# 2934              Children & Family Movies
# 3500  Action & Adventure, Sci-Fi & Fantasy
#
#                                             description
# 2934  When Ultron seizes control of Iron Man's armor...
# ...

# %%
list_avengers = [] 
#column_name = 'title'
for i in avengers_movies['title']:
    list_avengers.append(i)

# %%
list_avengers
# Out:
# ['LEGO Marvel Super Heroes: Avengers Reassembled!', 'Avengers: Infinity War']

# %%
top_countries = df2.sort_values(ascending= False)

# %%
top_countries.head(5)
# Out:
# country         type
# United States   Movie    1819
# India           Movie     868
# United Kingdom  Movie     164
# Canada          Movie     104
# Egypt           Movie      90
# dtype: int64

# %%
df_new = df[((df['country'] == "United States") & (df['type'] == "Movie")) | ((df['country'] == "India") & (df['type'] == "Movie")) | ((df['country'] == "United Kingdom") & (df['type'] == "Movie")) | 
((df['country'] == "Canada") & (df['type'] == "Movie")) | ((df['country'] == "Egypt") & (df['type'] == "Movie"))]

# %%
df_new.reset_index(drop = True)
# Out:
#       index show_id   type         title          director  \
# 0         9     s10  Movie  The Starling    Theodore Melfi
# 1        24     s25  Movie         Jeans        S. Shankar
# 2        27     s28  Movie     Grown Ups      Dennis Dugan
# 3        28     s29  Movie    Dark Skies     Scott Stewart
# 4        41     s42  Movie          Jaws  Steven Spielberg
# ...     ...     ...    ...           ...               ...
# 3040   8799   s8800  Movie         Zenda    Avadhoot Gupte
# 3041   8802   s8803  Movie        Zodiac     David Fincher
# 3042   8804   s8805  Movie    Zombieland   Ruben Fleischer
# 3043   8805   s8806  Movie          Zoom      Peter Hewitt
# 3044   8806   s8807  Movie        Zubaan       Mozez Singh
#
#                                                    cast        country  \
# 0     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 1     Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...          India
# ...

# %%
df_new1 = df[((df['country'] == "United States")) | ((df['country'] == "India")) | ((df['country'] == "United Kingdom")) | 
((df['country'] == "Canada")) | ((df['country'] == "Egypt"))]

# %%
df_new1
# Out:
#       index show_id     type                          title         director  \
# 1         8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 2         9     s10    Movie                   The Starling   Theodore Melfi
# 4        24     s25    Movie                          Jeans       S. Shankar
# 5        27     s28    Movie                      Grown Ups     Dennis Dugan
# 6        28     s29    Movie                     Dark Skies    Scott Stewart
# ...     ...     ...      ...                            ...              ...
# 5326   8799   s8800    Movie                          Zenda   Avadhoot Gupte
# 5328   8802   s8803    Movie                         Zodiac    David Fincher
# 5329   8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 5330   8805   s8806    Movie                           Zoom     Peter Hewitt
# 5331   8806   s8807    Movie                         Zubaan      Mozez Singh
#
# ...

# %%
df_new1.reset_index(drop = True)
# Out:
#       index show_id     type                          title         director  \
# 0         8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 1         9     s10    Movie                   The Starling   Theodore Melfi
# 2        24     s25    Movie                          Jeans       S. Shankar
# 3        27     s28    Movie                      Grown Ups     Dennis Dugan
# 4        28     s29    Movie                     Dark Skies    Scott Stewart
# ...     ...     ...      ...                            ...              ...
# 3096   8799   s8800    Movie                          Zenda   Avadhoot Gupte
# 3097   8802   s8803    Movie                         Zodiac    David Fincher
# 3098   8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 3099   8805   s8806    Movie                           Zoom     Peter Hewitt
# 3100   8806   s8807    Movie                         Zubaan      Mozez Singh
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
small_country_df = df_new[(df_new['type'] == "Movie") & ((df_new['country'] == "United States") | (df_new['country'] == "India") |
                                                         (df_new['country'] == "United Kingdom") | (df_new['country'] == "Canada") |
                                                         (df_new['country'] == "Egypt"))]

# %%
small_country_df.reset_index(drop = True)
# Out:
#       index show_id   type         title          director  \
# 0         9     s10  Movie  The Starling    Theodore Melfi
# 1        24     s25  Movie         Jeans        S. Shankar
# 2        27     s28  Movie     Grown Ups      Dennis Dugan
# 3        28     s29  Movie    Dark Skies     Scott Stewart
# 4        41     s42  Movie          Jaws  Steven Spielberg
# ...     ...     ...    ...           ...               ...
# 3040   8799   s8800  Movie         Zenda    Avadhoot Gupte
# 3041   8802   s8803  Movie        Zodiac     David Fincher
# 3042   8804   s8805  Movie    Zombieland   Ruben Fleischer
# 3043   8805   s8806  Movie          Zoom      Peter Hewitt
# 3044   8806   s8807  Movie        Zubaan       Mozez Singh
#
#                                                    cast        country  \
# 0     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 1     Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...          India
# ...

# %%
small_df2 = small_country_df.groupby(['country' , 'type']).size().reset_index(name = 'number of movies')

# %%
small_df2
# Out:
#           country   type  number of movies
# 0          Canada  Movie               104
# 1           Egypt  Movie                90
# 2           India  Movie               868
# 3  United Kingdom  Movie               164
# 4   United States  Movie              1819

# %%
small_df2.sort_values(by = 'number of movies',ascending = False).reset_index(drop = True)
# Out:
#           country   type  number of movies
# 0   United States  Movie              1819
# 1           India  Movie               868
# 2  United Kingdom  Movie               164
# 3          Canada  Movie               104
# 4           Egypt  Movie                90

# %%
plt.pie(small_df2['number of movies'], labels=small_df2['country'], autopct='%1.2f%%',startangle=140)
plt.title('All Movies Pie Chart')
# Out:
# Text(0.5, 1.0, 'All Movies Pie Chart')
