# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
 df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df['gender'].unique()
# Out:
# <bound method Series.unique of 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object>

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.loc[0,"gender"]
# Out:
# 'female'

# %%
df.iloc[0,4]
# Out:
# 'none'

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
new_row = {'gender' :'female','race/ethnicity' : 'group B','parental level of education': 'batchelors degree', 'lunch' : 'standard','test preparation course' :'none','math score': 100,'reading score':100,'writing score':100}

# %%
new_row
# Out:
# {100, 'batchelors degree', 'female', 'group B', 'none', 'standard'}

# %%
df.loc[len(df)] = new_row

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           batchelors degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996     male        group C                 high school  free/reduced
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1001  female        group B           batchelors degree      standard
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[1000,'lunch'] = "yes"

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           batchelors degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1001  female        group B           batchelors degree      standard
# 1000     NaN            NaN                         NaN           yes
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           batchelors degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none       100.0          100.0          100.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           batchelors degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1001  female        group B           batchelors degree      standard
# 1000     NaN            NaN                         NaN           yes
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df = df.fillna(np.mean(df, axis = 0))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           batchelors degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1001  female        group B           batchelors degree      standard
# 1000     NaN            NaN                         NaN           yes
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
xpoints = np.array([0,35,70])
ypoints = np.array([0,25,50])

plt.figure(figsize = (15,7))
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.title('Coordinates')
plt.plot(xpoints,ypoints,marker='*')
plt.show()

# %%
xpoint1 = np.array([0,10,73,118])
ypoint2 =np.array([0,130,123,11])
plt.scatter(xpoint1,ypoint2,marker='*')
plt.show()

# %%
value_counts = df['race/ethnicity'].value_counts()

# %%
plt.bar(value_counts.index , value_counts.values)
plt.show()

# %%
plt.barh(value_counts.index,value_counts.values)
plt.show()
